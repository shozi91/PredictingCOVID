# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv("NHA indicators.csv",encoding = 'ISO-8859-1')
df.columns = ['Countries', '2017 Health Budget per Capita ($)']
df
# Out:
#                               Countries 2017 Health Budget per Capita ($)
# 0                                  Niue                                 -
# 1                          Saudi Arabia                                 -
# 2                               Albania                                 -
# 3              United States of America                             10246
# 4                           Switzerland                              9956
# 5                                Norway                              7936
# 6                               Iceland                              6086
# 7                                Sweden                              5905
# 8                               Denmark                              5800
# 9                            Luxembourg                              5783
# 10                            Australia                              5332
# 11                              Germany                              5033
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-7455c66291a4> in <module>
#       4     try:
# ----> 5         medical[df['Countries'][country]['data']['name']] = medical['Countries'][country]['data']['people']['hospital_bed_density']['beds_per_1000_population']
#       6     except Exception as ex:
#
# KeyError: 'Countries'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-7455c66291a4> in <module>
#       7         #print(f"{cia['countries'][country]['data']['name']} does not have data")
#       8         #print(ex)
# ----> 9         medical[df['Countries'][country]['data']['name']] = ''
#      10
#      11
#
# TypeError: string indices must be integers
